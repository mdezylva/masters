# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir("/home/mitchell/Documents/masters/masters/data/server/run_10")
os.getcwd()
# Out:
# '/home/mitchell/Documents/masters/masters/data/server/run_10'

# %%
glob.glob("*")
# Out:
# ['output_130000.txt',
#  'output_70000.png',
#  'output_110000.png',
#  'output_0.txt',
#  'output_150000.txt',
#  'output_70000.txt',
#  'output_40000.txt',
#  'output_140000.txt',
#  'output_180000.txt',
#  'output_190000.png',
#  'output_120000.png',
#  'output_10000.txt',
#  'output_190000.txt',
#  'output_30000.png',
#  'output_130000.png',
#  'output_120000.txt',
#  'output_50000.png',
#  'output_30000.txt',
#  'output_80000.txt',
#  'output_50000.txt',
#  'output_100000.txt',
#  'output_160000.txt',
#  'output_0.png',
#  'output_80000.png',
#  'output_10000.png',
#  'output_150000.png',
#  'output_180000.png',
#  'output_140000.png',
#  'output_100000.png',
#  'output_160000.png',
#  'output_110000.txt',
#  'output_40000.png']

# %%
output = np.loadtxt('output_190000.txt',delimiter=',')

# %%
plt.imshow(output)

# %%
central_line = output[60,:]

# %%
plt.plot(central_line)
